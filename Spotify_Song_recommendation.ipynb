# %%
import pandas as pd
import numpy as np

# %%
song_data=pd.read_csv("song_data.csv")
song_data.head()

# %%
count=pd.read_csv("10000.txt",sep="\t",header=None,names=['user','song_id','rating'])
count.head()

# %%
#We will be first using a collaborative approach and later a content based approach on the artist_name

# %%
merged=pd.merge(count,song_data,on="song_id")
merged.head()

# %%
merged.groupby(["user","song_id"]).size().reset_index().rename(columns={0:'num'}).sort_values("num",ascending=False)

# %%
#We have a mximum of a user rating a song 3 times we will take the average of these ratings because all ratings are different
new_rating=merged.groupby(["user","song_id"])["rating"].mean().reset_index().rename(columns={"rating":"new_rating"})
new_df=pd.merge(new_rating,merged,on=["user","song_id"])
new_df.head()
# Out:
#                                        user             song_id  new_rating  \
# 0  00003a4459f33b92906be11abe0e93efc423c0ff  SOJJRVI12A6D4FBE49         1.0
# 1  00003a4459f33b92906be11abe0e93efc423c0ff  SOKJWZB12A6D4F9487         4.0
# 2  00003a4459f33b92906be11abe0e93efc423c0ff  SOMZHIH12A8AE45D00         3.0
# 3  00003a4459f33b92906be11abe0e93efc423c0ff  SONFEUF12AAF3B47E3         3.0
# 4  00003a4459f33b92906be11abe0e93efc423c0ff  SOVMGXI12AF72A80B0         1.0
#
#    rating                                              title  \
# 0       1                Only You (Illuminate Album Version)
# 1       4  Do You Want To Know Love (Pray For Rain Album ...
# 2       3                              You're A Wolf (Album)
# 3       3                                     Não É Proibido
# 4       1                                           Hey Mama
#
#                release         artist_name  year
# 0           Illuminate  David Crowder*Band  2003
# 1     Very Best Of PFR                 PFR     0
# 2  Leaves In The River            Sea Wolf  2007
# 3       Não É Proibido        Marisa Monte     0
# 4             Elephunk     Black Eyed Peas  2003

# %%
new_df[["new_rating","rating"]]
# Out:
#          new_rating  rating
# 0               1.0       1
# 1               4.0       4
# 2               3.0       3
# 3               3.0       3
# 4               1.0       1
# ...             ...     ...
# 2086941         1.0       1
# 2086942         1.0       1
# 2086943         1.0       1
# 2086944         1.0       1
# 2086945         1.0       1
#
# [2086946 rows x 2 columns]

# %%
analysis=new_df.groupby("song_id").agg(
avg_rating=("new_rating","mean"),
rating_count=("new_rating","count"))

# %%
#We can see that lot of songs have a very low rating count
# %matplotlib inline
import matplotlib.pyplot as plt
analysis['rating_count'].hist(bins=50, figsize=(10,4))
plt.show()

# %%
analysis['rating_count'].describe()
# Out:
# count    10000.000000
# mean       208.694600
# std        351.823049
# min         48.000000
# 25%         89.000000
# 50%        126.000000
# 75%        205.000000
# max       8277.000000
# Name: rating_count, dtype: float64

# %%
analysis.sort_values(by="rating_count")
# Out:
#                     avg_rating  rating_count
# song_id
# SOYYBJJ12AB017E9FD    2.395833            48
# SOGSPGJ12A8C134FAA    3.166667            48
# SOBPGWB12A6D4F7EF3    5.400000            50
# SOWNLZF12A58A79811    2.980392            51
# SOLIGVL12AB017DBAE    2.098039            51
# ...                        ...           ...
# SOBONKR12A58A7A7E0    8.442920          6412
# SOAXGDH12A8C13F8A1    3.836955          6949
# SOAUWYT12A81C206F1    7.004124          7032
# SOWCKVR12A8C142411    2.784205          7952
# SOFRQTD12A81C233C0    3.749668          8277
#
# [10000 rows x 2 columns]

# %%
#Lets take only songs_with more than 125 rating_counts to include songs with higher reach
count_filter=analysis[analysis['rating_count']>125].index
count_filter
# Out:
# Index(['SOAACPJ12A81C21360', 'SOAAFAC12A67ADF7EB', 'SOAAFYH12A8C13717A',
#        'SOAAROC12A6D4FA420', 'SOAATLI12A8C13E319', 'SOAAUKC12AB017F868',
#        'SOAAVUV12AB0186646', 'SOAAWEE12A6D4FBEC8', 'SOABHYV12A6D4F6D0F',
#        'SOABJBU12A8C13F63F',
#        ...
#        'SOZYDZR12A8C13F4F0', 'SOZYSDT12A8C13BFD7', 'SOZYUGZ12A8AE472AC',
#        'SOZYUXF12A6701F7B9', 'SOZZHQT12AB018B714', 'SOZZIOH12A67ADE300',
#        'SOZZLZN12A8AE48D6D', 'SOZZTCU12AB0182C58', 'SOZZTNF12A8C139916',
#        'SOZZVWB12AB0189C30'],
#       dtype='object', name='song_id', length=5013)

# %%
filter_applied=new_df[new_df['song_id'].isin(count_filter)]
filter_applied.head()
# Out:
#                                        user             song_id  new_rating  \
# 0  00003a4459f33b92906be11abe0e93efc423c0ff  SOJJRVI12A6D4FBE49         1.0
# 3  00003a4459f33b92906be11abe0e93efc423c0ff  SONFEUF12AAF3B47E3         3.0
# 4  00003a4459f33b92906be11abe0e93efc423c0ff  SOVMGXI12AF72A80B0         1.0
# 6  00003a4459f33b92906be11abe0e93efc423c0ff  SOWVBDQ12A8C13503D         3.0
# 8  00005c6177188f12fb5e2e82cdbd93e8a3f35e64  SOGMLQO12A670207BF         1.0
#
#    rating                                title         release  \
# 0       1  Only You (Illuminate Album Version)      Illuminate
# 3       3                       Não É Proibido  Não É Proibido
# 4       1                             Hey Mama        Elephunk
# 6       3                              Volveré        A Tiempo
# 8       1        What Difference Does It Make?      The Smiths
#
#           artist_name  year
# 0  David Crowder*Band  2003
# 3        Marisa Monte     0
# 4     Black Eyed Peas  2003
# 6          Gian Marco     0
# 8          The Smiths  1984

# %%
final_df=filter_applied.drop("rating",axis=1)
final_df.head()
# Out:
#                                        user             song_id  new_rating  \
# 0  00003a4459f33b92906be11abe0e93efc423c0ff  SOJJRVI12A6D4FBE49         1.0
# 3  00003a4459f33b92906be11abe0e93efc423c0ff  SONFEUF12AAF3B47E3         3.0
# 4  00003a4459f33b92906be11abe0e93efc423c0ff  SOVMGXI12AF72A80B0         1.0
# 6  00003a4459f33b92906be11abe0e93efc423c0ff  SOWVBDQ12A8C13503D         3.0
# 8  00005c6177188f12fb5e2e82cdbd93e8a3f35e64  SOGMLQO12A670207BF         1.0
#
#                                  title         release         artist_name  \
# 0  Only You (Illuminate Album Version)      Illuminate  David Crowder*Band
# 3                       Não É Proibido  Não É Proibido        Marisa Monte
# 4                             Hey Mama        Elephunk     Black Eyed Peas
# 6                              Volveré        A Tiempo          Gian Marco
# 8        What Difference Does It Make?      The Smiths          The Smiths
#
#    year
# 0  2003
# 3     0
# 4  2003
# 6     0
# 8  1984

# %% [markdown]
# # Collaborative Approach

# %%
import re  #Importing regular expression library

def clean_title(title):
  return re.sub("[^a-zA-Z0-9]"," ",title)

# %%
final_df['clean_title']=final_df['title'].apply(clean_title)

# %%
pivoted_df=final_df.pivot_table(index="clean_title",columns="user",values="new_rating").fillna(0)
pivoted_df
# Out:
# user                           00003a4459f33b92906be11abe0e93efc423c0ff  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           00005c6177188f12fb5e2e82cdbd93e8a3f35e64  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           00030033e3a2f904a48ec1dd53019c9969b6ef1f  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           0007235c769e610e3d339a17818a5708e41008d9  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           0007c0e74728ca9ef0fe4eb7f75732e8026a278b  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           000a5c8b4d8b2c98f7a205219181d039edcd4506  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           000b474f815bcff17a4bc9ce5324f9352dafe07d  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           000b4e4134d5f77d7608fbf86fb3e1adac4478a8  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           000b9a54ef0560b957ee0f7a4cb933c36025e600  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           000d2df2cb8ad7300f89512f8fe8fadc4f99e733  ...  \
# clean_title                                                              ...
#    Baby One More Time                                               0.0  ...
#   Come Around                                                       0.0  ...
#   Down                                                              0.0  ...
#  40                                                                 0.0  ...
#  Antichrist Television Blues                                        0.0  ...
# ...                                                                 ...  ...
# mOBSCENE                                                            0.0  ...
# paranoid android                                                    0.0  ...
# re stacks                                                           0.0  ...
# sillyworld  Album Version                                           0.0  ...
# sun drums and soil                                                  0.0  ...
#
# user                           fff877d23bf5b31fa2b013f51a7f939f12c374f2  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffa7a01e539be1f23e471503f29d8acb3c0ce7c  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffad4a128cd3d130f06c0f7bf493781081afe3c  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffb701ee87a32eff67eb040ed59146121f01571  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffc0df75a48d823ad5abfaf2a1ee61eb1e3302c  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffce9c1537fbc350ea68823d956eaa8f5236dbe  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffd6a2bdef646ce9898b628d5dd56c43df69a9d  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffd9635b33f412de8ed02e44e6564e3644cf3c6  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffe6d1d8500f1c1f31bd63abce35c0f975a86bf  \
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# user                           fffea3d509760c984e7d40789804c0e5e289cc86
# clean_title
#    Baby One More Time                                               0.0
#   Come Around                                                       0.0
#   Down                                                              0.0
#  40                                                                 0.0
#  Antichrist Television Blues                                        0.0
# ...                                                                 ...
# mOBSCENE                                                            0.0
# paranoid android                                                    0.0
# re stacks                                                           0.0
# sillyworld  Album Version                                           0.0
# sun drums and soil                                                  0.0
#
# [4899 rows x 75510 columns]

# %%
#Creating array_matrix
from scipy.sparse import csr_matrix
song_features=csr_matrix(pivoted_df.values)

# %%
#Creating Knn model using cosine similarity
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric="cosine",algorithm="brute")
model_knn.fit(song_features)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index='Down By The Water'
distances,indices=model_knn.kneighbors(pivoted_df.loc[query_index,:].values.reshape(1,-1),n_neighbors=6)

# %%
similar_songs=[]
for i in range(0,len(distances.flatten())):
    similar_songs.append(pivoted_df.index[indices.flatten()[i]])
similar_songs
# Out:
# ['Down By The Water',
#  'Talk Shows On Mute',
#  'She s So Cold',
#  'She s So Cold  1994 Digital Remaster ',
#  'Diary',
#  'Unprotected Sex With Multiple Partners']

# %%
def knn_collab(ids):
    query_index=clean_title(ids)
    distances,indices=model_knn.kneighbors(pivoted_df.loc[query_index,:].values.reshape(1,-1),n_neighbors=6)
    collaborative_indexes=[]
    for i in range(0,len(distances.flatten())):
        collaborative_indexes.append(pivoted_df.index[indices.flatten()[i]])
    knn_result=final_df[final_df["clean_title"].isin(collaborative_indexes)]['clean_title'].unique()
    results=song_data[song_data['title'].isin(knn_result)]
    return results

# %%
knn_collab("Down By The Water")
# Out:
#                    song_id                                   title  \
# 16105   SOEJMDR12A58A7E62A                      Talk Shows On Mute
# 35578   SOCKGYC12AB018CB4C                                   Diary
# 49020   SOGIVSP12AF729A146                       Down By The Water
# 83329   SOTKTVX12A58A7DD8D                                   Diary
# 116278  SOYAFGE12A8C13761E                      Talk Shows On Mute
# 213573  SOZBEEE12A8C132C72                                   Diary
# 373997  SOTLQWL12AB018167B  Unprotected Sex With Multiple Partners
# 380571  SOXIEVW12A8C13DC32                                   Diary
# 474887  SOWRMDY12A8C13EEAE                                   Diary
# 497479  SOQEPKZ12AB0187B66                                   Diary
# 530282  SOAWJSH12A8C13AE09                                   Diary
# 591653  SOXIEVW12A8C13DC32                                   Diary
# 605773  SODTIJM12A8C138557                      Talk Shows On Mute
# 715675  SOKCLCQ12A6D4F6F71                                   Diary
# 718631  SOMKNUK12AF72AA9B9                                   Diary
# 774752  SOZGCXY12AC468A141                                   Diary
# 799314  SOGUCIK12A8C140E3A                                   Diary
# 805242  SOIDHAU12AB017A46F                                   Diary
# 933734  SOCSETK12AB0182845                                   Diary
# 977000  SOZKHFN12A8C13E2D0                                   Diary
# 994504  SOJMVEB12A8C13D0CB                                   Diary
#
#                                              release  \
# 16105                            Live In Sweden 2004
# 35578                       Small Lights in the Dark
# 49020                           To Bring You My Love
# 83329                                           Lies
# 116278                  A Crow Left Of The Murder...
# 213573  The Moon & The Banana Tree-Madagascar Guitar
# 373997                Searching For A Former Clarity
# 380571                                     Unplugged
# 474887                   Dance Vault Remixes - Diary
# 497479                          Flair For Darjeeling
# 530282                      The Diary Of Alicia Keys
# 591653                                     Unplugged
# 605773                         Live in Malaysia 2004
# 715675                                Ex Girlfriends
# 718631                   Dance Vault Remixes - Diary
# 774752                            Love Will Find You
# 799314                                      Playlist
# 805242                                   Back 2 Back
# 933734                                Sound On Sound
# 977000                   Dance Vault Remixes - Diary
# 994504                    No Vacation From The World
#
#                                               artist_name  year
# 16105                                             Incubus  2003
# 35578                                               Lunik  2010
# 49020                                           PJ Harvey  1995
# 83329                                          Bon Voyage  2008
# 116278                                            Incubus  2003
# 213573                                        Bob Baldwin     0
# 373997                                        Against Me!  2005
# 380571                                        Alicia Keys  2005
# 474887  Alicia Keys featuring Tony! Toni! Toné! and Je...  2005
# 497479                                The Loch Ness Mouse  1999
# 530282  Alicia Keys featuring Tony! Toni! Toné! and Je...  2005
# 591653                                        Alicia Keys  2005
# 605773                                            Incubus  2003
# 715675                                       Low Millions  2004
# 718631  Alicia Keys featuring Tony! Toni! Toné! and Je...  2005
# 774752                          Saturday Looks Good To Me  2002
# 799314                           Kenny "Babyface" Edmonds     0
# 805242                                           Stargard     0
# 933734                          Saturday Looks Good To Me  2002
# 977000  Alicia Keys featuring Tony! Toni! Toné! and Je...  2005
# 994504                                       Useless I.D.     0

# %%
titles=['Down By The Water',
 'Talk Shows On Mute',
 'She s So Cold',
 'She s So Cold  1994 Digital Remaster ',
 'Diary']

# %%
combined_df_list = []  # List to store individual DataFrames

for i in titles:
    df = knn_collab(i)  # Get DataFrame for each title
    combined_df_list.append(df)  # Append each DataFrame to the list

# Combine all DataFrames in the list vertically
combined_df = pd.concat(combined_df_list, ignore_index=True)

# Now, combined_df contains the concatenated DataFrame of all outputs
combined_df
# Out:
#                 song_id               title                       release  \
# 0    SOEJMDR12A58A7E62A  Talk Shows On Mute           Live In Sweden 2004
# 1    SOCKGYC12AB018CB4C               Diary      Small Lights in the Dark
# 2    SOGIVSP12AF729A146   Down By The Water          To Bring You My Love
# 3    SOTKTVX12A58A7DD8D               Diary                          Lies
# 4    SOYAFGE12A8C13761E  Talk Shows On Mute  A Crow Left Of The Murder...
# ..                  ...                 ...                           ...
# 235  SOGUCIK12A8C140E3A               Diary                      Playlist
# 236  SOIDHAU12AB017A46F               Diary                   Back 2 Back
# 237  SOCSETK12AB0182845               Diary                Sound On Sound
# 238  SOZKHFN12A8C13E2D0               Diary   Dance Vault Remixes - Diary
# 239  SOJMVEB12A8C13D0CB               Diary    No Vacation From The World
#
#                                            artist_name  year
# 0                                              Incubus  2003
# 1                                                Lunik  2010
# 2                                            PJ Harvey  1995
# 3                                           Bon Voyage  2008
# 4                                              Incubus  2003
# ..                                                 ...   ...
# 235                           Kenny "Babyface" Edmonds     0
# 236                                           Stargard     0
# 237                          Saturday Looks Good To Me  2002
# 238  Alicia Keys featuring Tony! Toni! Toné! and Je...  2005
# 239                                       Useless I.D.     0
#
# [240 rows x 5 columns]

# %% [markdown]
# # Content Based

# %%
song_data.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name  year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003
# 1                           Karkuteillä  Karkkiautomaatti  1995
# 2                                Butter    Hudson Mohawke  2006
# 3                               De Culo       Yerba Brava  2003
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1634169 entries, 0 to 2086945
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   user         1634169 non-null  object
#  1   song_id      1634169 non-null  object
#  2   new_rating   1634169 non-null  float64
#  3   title        1634169 non-null  object
#  4   release      1634169 non-null  object
#  5   artist_name  1634169 non-null  object
#  6   year         1634169 non-null  int64
#  7   clean_title  1634169 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 112.2+ MB

# %%
song_data_copy=song_data

# %%
song_data=song_data[song_data['title'].isin(final_df['title'])]

# %%
print(song_data.shape)
print(song_data_copy.shape)
# Out:
# (34960, 5)
# (1000000, 5)

# %%
import re

def clean_title2(title):
    if isinstance(title, str):  # Check if input is a string
        return re.sub("[^a-zA-Z0-9]", " ", title)
    else:
        return ""

# %%
song_data['clean_title']=song_data['title'].apply(clean_title2)
# Out:
# <ipython-input-33-8e1e548b83b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_data['clean_title']=song_data['title'].apply(clean_title2)

# %%
song_data['comb']=song_data['title']+song_data['artist_name'].astype(str)
# Out:
# <ipython-input-34-0864a7567904>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_data['comb']=song_data['title']+song_data['artist_name'].astype(str)

# %%
song_data['comb']=song_data['comb'].apply(clean_title2)
# Out:
# <ipython-input-35-dd5253628e09>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   song_data['comb']=song_data['comb'].apply(clean_title2)

# %%
song_data['comb'].head()
# Out:
# 8                   GoodbyeJoseph Locke
# 29                        TequilaPiotta
# 47                     ScreamBilly Idol
# 69                      You And IChasen
# 100    SuperstitionBeck  Bogert  Appice
# Name: comb, dtype: object

# %%
# Based on title
#For a content Based Approach we will use Names
from sklearn.feature_extraction.text import TfidfVectorizer
tfv=TfidfVectorizer(ngram_range=(1,3))
from sklearn.metrics.pairwise import cosine_similarity
title_vector=tfv.fit_transform(song_data['comb'])

# %%
def content_rec(entered_title):
    cleaned_title=clean_title(entered_title)
    new=tfv.transform([cleaned_title])
    similar_title=cosine_similarity(new,title_vector).flatten()
    indx=np.argpartition(similar_title,-10)[-10:]
    result = song_data.iloc[indx][::-1]
    return result

# %% [markdown]
# # Hybrid Recommendation
#
# * Step 1 : Entering song name along with year to get your song
# * Step 2 :From the similiar titles found from step 1 assuming your song would be in the top 5 we will take top 5 title and from these use the titles that have greter rating and recommend based upon it
# * Step 3 :Find collaborative recommendations of these 3 titles and order it first from similar 3 movies followed by collaborative recommendation of first movie followed by rest 3

# %%
def final_recommendation(movie_title,number):
  songs=content_rec(movie_title)

  finding_collab_song=songs[songs['title'].isin(final_df['title'])]['title'].unique()


  combined_df_list = []  # List to store individual DataFrames

  for i in finding_collab_song:
      df = knn_collab(i)  # Get DataFrame for each title
      combined_df_list.append(df)  # Append each DataFrame to the list

  if len(combined_df_list)<=0:
    combined_df=None
  else:
    combined_df = pd.concat(combined_df_list, ignore_index=True)

  if combined_df is None:
    return songs
  else:
    return pd.concat([songs,combined_df],ignore_index=True).head(number)

  #Now Combine content based and collaborative filtering together

# %%
final_recommendation(" ozzy ozborn",20)
# Out:
#                song_id           title                       release  \
# 0   SONRGQV12A8C13CB4C           Lucky                   Treatment 5
# 1   SOADWIU12AB017E8A1         Love Me                          Exit
# 2   SOQDBOA12A8C13E5E6            Rain             The Broken String
# 3   SOOTYEZ12AC4687F68         Hold On        Steppin' It Up A Notch
# 4   SOMTUVP12A8C13DC25  My Moon My Man                 I Feel It All
# 5   SOBMHQS12AB018275F        Violence                    För Väntan
# 6   SOWBUPG12AB0189CA5      No Remorse            Back from the Path
# 7   SOONPYA12AB0185A6F      All I Want                       Celsius
# 8   SOIHLQA12A58A76F7D           Venus                 Closure: Live
# 9   SOPIUMG12A6D4F7059       Let Me Go                  Street Music
